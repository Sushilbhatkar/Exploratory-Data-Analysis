# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
df.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %%
# #plot a corr map for all numeric variables 
plt.figure(figsize=(20, 20))
corr = df.select_dtypes(include='number').corr()

sns.heatmap(corr,annot=True,fmt='.2f',cmap='coolwarm',linewidths=0.5)

plt.title("Correlation Heatmap of Numeric Variables", fontsize=16)
plt.show()

# %%
#We'd now eplore the number of people based on different criteria to see which criteria is the dominat one for attrition

#count of pepole doing overtime 
sns.countplot(df["OverTime"])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title("OverTime")
# Out:
# Text(0.5, 1.0, 'OverTime')

# %%
#count of pepole based on their marital status
sns.countplot(df['MaritalStatus'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title("Marital Status")
# Out:
# Text(0.5, 1.0, 'Marital Status')

# %%
#count the people based on there Jobrole
sns.countplot(df['JobRole'])
fig = plt.gcf()
fig.set_size_inches(20,14)
plt.title("Job Role")
# Out:
# Text(0.5, 1.0, 'Job Role')

# %%
#count of people based on thier Gender 
sns.countplot(df["Gender"])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title("Gender")
# Out:
# Text(0.5, 1.0, 'Gender')

# %%
#count of pepole based on their field of education
sns.countplot(df['EducationField'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Education Field')
# Out:
# Text(0.5, 1.0, 'Education Field')

# %%
#count of people based on the department in which they work
sns.countplot(df['Department'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Department')
# Out:
# Text(0.5, 1.0, 'Department')

# %%
#count of people based on their Travel frequency
sns.countplot(df['BusinessTravel'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Business Travel')
# Out:
# Text(0.5, 1.0, 'Business Travel')

# %%
#analyzing the age group of the pepole doing overtime 
sns.catplot(x="OverTime",y="Age",kind="swarm",data=df)

# %%
#count of people based on their total working years
plt.figure(figsize=(15, 5))
sns.countplot(x=df['TotalWorkingYears'])
plt.title('Count of Employees by Total Working Years')
plt.xlabel('Total Working Years')
plt.ylabel('Count')
plt.show()

# %%
#count of people based on their Education
plt.figure(figsize=(15, 5))
sns.countplot(x=df['Education'])
plt.title('Count of Employees by Education Level')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.show()

# %%
#count of people based on the number of companies they have worked for 
plt.figure(figsize=(15, 5))
sns.countplot(x=df['NumCompaniesWorked'])
plt.title('count of people based on the number of companies they have worked ')
plt.xlabel('NumCompaniesWorked')
plt.ylabel('Count')
plt.show()

# %%
#count of people based on the distance from home they are working 
plt.figure(figsize=(15, 5))
sns.countplot(x=df['DistanceFromHome'])
plt.title('count of people based on the distance from home they are working')
plt.xlabel('DistanceFromHome')
plt.ylabel('Count')
plt.show()
