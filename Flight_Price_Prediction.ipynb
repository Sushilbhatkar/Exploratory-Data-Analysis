# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_train = pd.read_excel("Data_Train.xlsx")
df_test= pd.read_excel("Test_set.xlsx")

# %% [markdown]
# df_train = Data_Train.xlsx

# %%
df_train.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df_train.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
df_train.shape
# Out:
# (10683, 11)

# %%
df_train.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df_train.describe().T
# Out:
#          count         mean          std     min     25%     50%      75%  \
# Price  10683.0  9087.064121  4611.359167  1759.0  5277.0  8372.0  12373.0
#
#            max
# Price  79512.0

# %% [markdown]
# df_test = Test_set.xlsx

# %%
df_test.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
df_test.shape
# Out:
# (2671, 10)

# %%
df_test.describe().T
# Out:
#                 count unique              top  freq
# Airline          2671     11      Jet Airways   897
# Date_of_Journey  2671     44        9/05/2019   144
# Source           2671      5            Delhi  1145
# Destination      2671      6           Cochin  1145
# Route            2671    100  DEL → BOM → COK   624
# Dep_Time         2671    199            10:00    62
# Arrival_Time     2671    704            19:00   113
# Duration         2671    320           2h 50m   122
# Total_Stops      2671      5           1 stop  1431
# Additional_Info  2671      6          No info  2148

# %%
df_test.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# dtype: int64

# %% [markdown]
# Removing Blank Values

# %%
df_train = df_train.dropna() #droping the NaN Value

# %%
df_train.shape
# Out:
# (10682, 11)

# %% [markdown]
# This means that there was only one row having missing values which we have removed

# %% [markdown]
# Converting the data type to data-time format and adding new columns

# %%
df_train['Journey_Day'] = pd.to_datetime(df_train.Date_of_Journey,format = '%d/%m/%Y').dt.day
df_train.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
#
#    Journey_Day
# 0           24
# 1            1
# 2            9
# 3           12
# ...

# %%
df_train['Journey_Month'] = pd.to_datetime(df_train.Date_of_Journey,format='%d/%m/%Y').dt.month
df_train.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
#
#    Journey_Day  Journey_Month
# 0           24              3
# 1            1              5
# ...

# %%
df_train['Year'] = pd.to_datetime(df_train.Date_of_Journey,format='%d/%m/%Y').dt.year
df_train.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
#
#    Journey_Day  Journey_Month  Year
# 0           24              3  2019
# ...

# %%
#For test dataset
df_test['Journey_Day'] = pd.to_datetime(df_test.Date_of_Journey,format = '%d/%m/%Y').dt.day

df_test['Journey_Month'] = pd.to_datetime(df_test.Date_of_Journey,format='%d/%m/%Y').dt.month

df_test['Year'] = pd.to_datetime(df_test.Date_of_Journey,format='%d/%m/%Y').dt.year

df_test.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info  \
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info
#
#    Journey_Day  Journey_Month  Year
# ...

# %% [markdown]
# Droping Column for train Dataset

# %%
df_train.drop(labels='Date_of_Journey',axis= 1,inplace= True)
df_train.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  Journey_Day  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897           24
# 1         13:15   7h 25m     2 stops         No info   7662            1
# 2  04:25 10 Jun      19h     2 stops         No info  13882            9
# 3         23:30   5h 25m      1 stop         No info   6218           12
# 4         21:35   4h 45m      1 stop         No info  13302            1
#
#    Journey_Month  Year
# 0              3  2019
# 1              5  2019
# 2              6  2019
# ...

# %% [markdown]
# Droping Column for test Dataset

# %%
df_test.drop(labels='Date_of_Journey',axis= 1,inplace= True)
df_test.head()
# Out:
#              Airline    Source Destination            Route Dep_Time  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK    17:30
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR    06:20
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK    19:15
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK    08:00
# 4           Air Asia  Banglore       Delhi        BLR → DEL    23:55
#
#    Arrival_Time Duration Total_Stops              Additional_Info  \
# 0  04:25 07 Jun  10h 55m      1 stop                      No info
# 1         10:20       4h      1 stop                      No info
# 2  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3         21:00      13h      1 stop                      No info
# 4  02:45 25 Jun   2h 50m    non-stop                      No info
#
#    Journey_Day  Journey_Month  Year
# 0            6              6  2019
# 1           12              5  2019
# 2           21              5  2019
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10682 entries, 0 to 10682
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10682 non-null  object
#  1   Source           10682 non-null  object
#  2   Destination      10682 non-null  object
#  3   Route            10682 non-null  object
#  4   Dep_Time         10682 non-null  object
#  5   Arrival_Time     10682 non-null  object
#  6   Duration         10682 non-null  object
#  7   Total_Stops      10682 non-null  object
#  8   Additional_Info  10682 non-null  object
#  9   Price            10682 non-null  int64
#  10  Journey_Day      10682 non-null  int32
#  11  Journey_Month    10682 non-null  int32
#  12  Year             10682 non-null  int32
# dtypes: int32(3), int64(1), object(9)
# memory usage: 1.0+ MB

# %%
#type casting for training dataset
#Converting text to  numerical in Duriation Column 

duration = list(df_train['Duration'])

for i in range(len(duration)):
    if len(duration[i].split()) != 2:
        if 'h' in duration[i]:
            duration[i] = duration[i].strip() +  ' 0m'
        elif 'm' in duration[i] :
            duration[i] = '0h {}'.format(duration[i].strip())

dur_hours = []
dur_minutes = []

for i in range(len(duration)) :
    dur_hours.append(int(duration[i].split()[0][:-1]))#for examole if duration is 49 mintutes 4 sec then it will reflect like
    dur_minutes.append(int(duration[i].split()[1][:-1]))#0:49:4 and if 2 hours 10 seconds then it will reflect like 2:0:10


df_train["Duration_hours"] = dur_hours
df_train["Duration_minutes"] = dur_minutes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 4
#       1 #type casting for training dataset
# ...

# %%
Drping orignal Duration Column 

df_train.drop(labels='Duration',axis = 1,inplace=True)

df_train.head()
# Out:
#   Cell In[57], line 1
#     Drping orignal Duration Column
#            ^
# SyntaxError: invalid syntax

# %%
df_train.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Total_Stops Additional_Info  Price  Journey_Day  \
# 0  01:10 22 Mar    non-stop         No info   3897           24
# 1         13:15     2 stops         No info   7662            1
# 2  04:25 10 Jun     2 stops         No info  13882            9
# 3         23:30      1 stop         No info   6218           12
# 4         21:35      1 stop         No info  13302            1
#
#    Journey_Month  Year  Duration_hours  Duration_minutes
# 0              3  2019               2                50
# ...

# %%
#type casting for test dataset
#Converting text to  numerical in Duriation Column 

durationT = list(df_test['Duration'])

for i in range(len(durationT)):
    if len(durationT[i].split()) != 2:
        if 'h' in durationT[i]:
            durationT[i] = durationT[i].strip() +  ' 0m'
        elif 'm' in duration[i] :
            durationT[i] = '0h {}'.format(durationT[i].strip())

dur_hours = []
dur_minutes = []

for i in range(len(durationT)) :
    dur_hours.append(int(duration[i].split()[0][:-1]))
    if(len(durationT[i].split())>1):
        dur_minutes.append(int(durationT[i].split()[1][:-1]))
    else:
        dur_minutes.append(int(0))

        
df_test["Duration_hours"] = dur_hours
df_test["Duration_minutes"] = dur_minutes

df_test.drop(labels="Duration",axis = 1,inplace=True)

# %%
df_test.head()
# Out:
#              Airline    Source Destination            Route Dep_Time  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK    17:30
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR    06:20
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK    19:15
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK    08:00
# 4           Air Asia  Banglore       Delhi        BLR → DEL    23:55
#
#    Arrival_Time Total_Stops              Additional_Info  Journey_Day  \
# 0  04:25 07 Jun      1 stop                      No info            6
# 1         10:20      1 stop                      No info           12
# 2  19:00 22 May      1 stop  In-flight meal not included           21
# 3         21:00      1 stop                      No info           21
# 4  02:45 25 Jun    non-stop                      No info           24
#
#    Journey_Month  Year  Duration_hours  Duration_minutes
# 0              6  2019               2                55
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10682 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Airline           10682 non-null  object
#  1   Source            10682 non-null  object
#  2   Destination       10682 non-null  object
#  3   Route             10682 non-null  object
#  4   Dep_Time          10682 non-null  object
#  5   Arrival_Time      10682 non-null  object
#  6   Total_Stops       10682 non-null  object
#  7   Additional_Info   10682 non-null  object
#  8   Price             10682 non-null  int64
#  9   Journey_Day       10682 non-null  int32
#  10  Journey_Month     10682 non-null  int32
#  11  Year              10682 non-null  int32
#  12  Duration_hours    10682 non-null  int64
#  13  Duration_minutes  10682 non-null  int64
# dtypes: int32(3), int64(3), object(8)
# memory usage: 1.1+ MB

# %%
#converting Dep_time to depart time hour and depart time minutes

df_train['Depart_Time_Hour'] = pd.to_datetime(df_train.Dep_Time).dt.hour
df_train['Depart_Time_Minutes'] = pd.to_datetime(df_train.Dep_Time).dt.minute

df_train.drop(labels='Dep_Time',axis=1,inplace=True)

df_train.head()
# Out:
# C:\Users\sushi\AppData\Local\Temp\ipykernel_22728\4227322293.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_train['Depart_Time_Hour'] = pd.to_datetime(df_train.Dep_Time).dt.hour
# C:\Users\sushi\AppData\Local\Temp\ipykernel_22728\4227322293.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_train['Depart_Time_Minutes'] = pd.to_datetime(df_train.Dep_Time).dt.minute
#        Airline    Source Destination                  Route  Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  04:25 10 Jun
# ...

# %%
#Converting Arr_time to arr time hour and arr time minutes 

df_train["Arr_Time_Hour"] = pd.to_datetime(df_train.Arrival_Time).dt.hour
df_train["Arr_Time_Minutes"] = pd.to_datetime(df_train.Arrival_Time).dt.minute

df_train.drop(labels="Arrival_Time",axis=1,inplace=True)
df_train.head()
# Out:
# C:\Users\sushi\AppData\Local\Temp\ipykernel_22728\3170478084.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_train["Arr_Time_Hour"] = pd.to_datetime(df_train.Arrival_Time).dt.hour
# C:\Users\sushi\AppData\Local\Temp\ipykernel_22728\3170478084.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_train["Arr_Time_Minutes"] = pd.to_datetime(df_train.Arrival_Time).dt.minute
#        Airline    Source Destination                  Route Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
# ...

# %%
# applying the same to test set
df_test['Depart_Time_Hour'] = pd.to_datetime(df_test.Dep_Time).dt.hour
df_test['Depart_Time_Minutes'] = pd.to_datetime(df_test.Dep_Time).dt.minute


df_test.drop(labels = 'Dep_Time', axis = 1, inplace = True)
df_test.head() # cheking the test set after transformation
# Out:
# C:\Users\sushi\AppData\Local\Temp\ipykernel_22728\2707755003.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_test['Depart_Time_Hour'] = pd.to_datetime(df_test.Dep_Time).dt.hour
# C:\Users\sushi\AppData\Local\Temp\ipykernel_22728\2707755003.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_test['Depart_Time_Minutes'] = pd.to_datetime(df_test.Dep_Time).dt.minute
#              Airline    Source Destination            Route  Arrival_Time  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK  04:25 07 Jun
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR         10:20
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK  19:00 22 May
# ...

# %%
df_test['Arr_Time_Hour'] = pd.to_datetime(df_test.Arrival_Time).dt.hour
df_test['Arr_Time_Minutes'] = pd.to_datetime(df_test.Arrival_Time).dt.minute

df_test.drop(labels = 'Arrival_Time', axis = 1, inplace = True)
df_test.head() # cheking the test set after transformation
# Out:
# C:\Users\sushi\AppData\Local\Temp\ipykernel_22728\3932149260.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_test['Arr_Time_Hour'] = pd.to_datetime(df_test.Arrival_Time).dt.hour
# C:\Users\sushi\AppData\Local\Temp\ipykernel_22728\3932149260.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_test['Arr_Time_Minutes'] = pd.to_datetime(df_test.Arrival_Time).dt.minute
#              Airline    Source Destination            Route Total_Stops  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK      1 stop
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR      1 stop
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK      1 stop
# ...
